# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

satdata = "clean_data.csv"

satdata = pd.read_csv(satdata)
satdata.head()
# Out:
#                             University       CITY State         ZIP  \
# 0  University of Puerto Rico-Aguadilla  Aguadilla    PR  00604-6150
# 1            Valdosta State University   Valdosta    GA       31698
# 2    University of Louisiana at Monroe     Monroe    LA  71209-0000
# 3    Southeastern Louisiana University    Hammond    LA       70402
# 4        Heritage Christian University   Florence    AL  35630-9977
#
#     LATITUDE  LONGITUDE  SAT_AVG_ALL  Total_EMP  Median_income  AVG_income
# 0  18.498652 -67.137930         1049      43380          19420       26900
# 1  30.847402 -83.289282         1059      52630          28840       37420
# 2  32.527748 -92.073740         1124      77540          30040       38340
# 3  30.514652 -90.468676         1085      43180          28980       38450
# 4  34.856153 -87.663051         1030      54340          30900       38530

# %%
satdata.columns
# Out:
# Index(['University', 'CITY', 'State', 'ZIP', 'LATITUDE', 'LONGITUDE',
#        'SAT_AVG_ALL', 'Total_EMP', 'Median_income', 'AVG_income'],
#       dtype='object')

# %%
column_table = satdata[["University", "CITY", "State","ZIP", "SAT_AVG_ALL"]]
column_table.head()
# Out:
#                             University       CITY State         ZIP  \
# 0  University of Puerto Rico-Aguadilla  Aguadilla    PR  00604-6150
# 1            Valdosta State University   Valdosta    GA       31698
# 2    University of Louisiana at Monroe     Monroe    LA  71209-0000
# 3    Southeastern Louisiana University    Hammond    LA       70402
# 4        Heritage Christian University   Florence    AL  35630-9977
#
#    SAT_AVG_ALL
# 0         1049
# 1         1059
# 2         1124
# 3         1085
# 4         1030

# %%
satdata.count()
# Out:
# University       579
# CITY             579
# State            579
# ZIP              579
# LATITUDE         557
# LONGITUDE        557
# SAT_AVG_ALL      579
# Total_EMP        579
# Median_income    579
# AVG_income       579
# dtype: int64

# %%
test_table = satdata.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

test_table.head()
# Out:
#                             University       CITY State         ZIP  \
# 0  University of Puerto Rico-Aguadilla  Aguadilla    PR  00604-6150
# 1            Valdosta State University   Valdosta    GA       31698
# 2    University of Louisiana at Monroe     Monroe    LA  71209-0000
# 3    Southeastern Louisiana University    Hammond    LA       70402
# 4        Heritage Christian University   Florence    AL  35630-9977
#
#     LATITUDE  LONGITUDE  SAT_AVG_ALL  Total_EMP  Median_income  AVG_income
# 0  18.498652 -67.137930         1049      43380          19420       26900
# 1  30.847402 -83.289282         1059      52630          28840       37420
# 2  32.527748 -92.073740         1124      77540          30040       38340
# 3  30.514652 -90.468676         1085      43180          28980       38450
# 4  34.856153 -87.663051         1030      54340          30900       38530

# %%
test_table.count()
# Out:
# University       557
# CITY             557
# State            557
# ZIP              557
# LATITUDE         557
# LONGITUDE        557
# SAT_AVG_ALL      557
# Total_EMP        557
# Median_income    557
# AVG_income       557
# dtype: int64

# %%
income_table = satdata[["State","ZIP", "SAT_AVG_ALL", "AVG_income"]]
income_table.head()

income_table = income_table.dropna(how='any')
income_table.head()
# Out:
#   State         ZIP  SAT_AVG_ALL  AVG_income
# 0    PR  00604-6150         1049       26900
# 1    GA       31698         1059       37420
# 2    LA  71209-0000         1124       38340
# 3    LA       70402         1085       38450
# 4    AL  35630-9977         1030       38530

# %%
SAT_summary =pd.DataFrame(test_table.groupby("State").count())


SAT_summary["Mean"] = pd.DataFrame(test_table.groupby("State")["SAT_AVG_ALL"].mean())
SAT_summary["Median"] = pd.DataFrame(test_table.groupby("State")["SAT_AVG_ALL"].median())
SAT_summary["Variance"] = pd.DataFrame(test_table.groupby("State")["SAT_AVG_ALL"].var())
SAT_summary["Std. Dev"] = pd.DataFrame(test_table.groupby("State")["SAT_AVG_ALL"].std())
SAT_summary["SEM"] = pd.DataFrame(test_table.groupby("State")["SAT_AVG_ALL"].sem())

SAT_summary = SAT_summary[["Mean","Median","Variance","Std. Dev", "SEM"]]

state_sat_table = SAT_summary.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)


state_sat_table['Rank'] = state_sat_table['Mean'].rank(method='max',ascending=False)



state_sat_table.head(46)
# Out:
# C:\Users\Choi9\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
#               Mean  Median      Variance    Std. Dev         SEM  Rank
# State
# AL     1138.875000  1127.5  12300.516667  110.907694   27.726924  25.0
# AR     1117.000000  1125.0  11238.000000  106.009434   47.408860  36.0
# AZ     1110.200000  1132.0  13604.700000  116.639187   52.162630  37.0
# CA     1168.653846  1161.5  17492.315385  132.258517   25.938029  14.0
# CO     1151.600000  1156.0   9549.155556   97.719781   30.901708  19.0
# CT     1186.666667  1249.0  48746.500000  220.786096   73.595365  10.0
# DC     1249.600000  1294.0  43697.300000  209.038992   93.485079   2.0
# ...

# %%
income_summary =pd.DataFrame(satdata.groupby("State").count())


income_summary["Mean"] = pd.DataFrame(satdata.groupby("State")["AVG_income"].mean())
income_summary["Median"] = pd.DataFrame(satdata.groupby("State")["AVG_income"].median())
income_summary["Variance"] = pd.DataFrame(satdata.groupby("State")["AVG_income"].var())
income_summary["Std. Dev"] = pd.DataFrame(satdata.groupby("State")["AVG_income"].std())
income_summary["SEM"] = pd.DataFrame(satdata.groupby("State")["AVG_income"].sem())

income_summary = income_summary[["Mean","Median","Variance","Std. Dev", "SEM"]]

state_income_table = income_summary.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)


state_income_table['Rank'] = state_income_table['Mean'].rank(method='max',ascending=False)



state_income_table.head(50)
# Out:
# C:\Users\Choi9\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
#                Mean  Median      Variance     Std. Dev          SEM  Rank
# State
# AL     44213.888889   42510  2.227806e+07  4719.964031  1112.506191  36.0
# AR     42970.000000   45020  1.254055e+07  3541.263899  1583.701361  44.0
# AZ     45775.000000   45235  2.005771e+07  4478.583960  1583.418544  29.0
# CA     56138.148148   57890  6.838856e+07  8269.737712  1591.511765   6.0
# CO     54415.000000   55435  4.701812e+07  6856.975767  2168.366128   8.0
# CT     60560.000000   60820  2.870498e+07  5357.702399  1785.900800   3.0
# ...
